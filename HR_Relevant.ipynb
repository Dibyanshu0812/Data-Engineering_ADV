# %% [markdown]
# ### Why are looking for a change

# %% [markdown]
# I’ve had a great learning journey at LTM, including my recent promotion to Senior Data Engineer. At this stage, I’m looking to take on more complex challenges and work on broader-scale data problems. This role aligns well with my interests and the kind of impact I want to create going forward.

# %% [markdown]
# ### Why Regined without any offer?

# %% [markdown]
# I’m on a 90-day notice period, and from my experience, many opportunities move faster than that. I made a calculated decision to resign early so I can be more flexible with joining timelines and not miss out on the right roles. I’ve planned this transition carefully, and I’m focused on finding a position that aligns well with my skills and long-term goals

# %% [markdown]
# ### Brief Intro

# %% [markdown]
# I’m a Data Engineer with around 2.6 years of experience, currently working as a Senior Data Engineer. I specialize in building and optimizing data pipelines using Python, SQL, and Azure services. Recently, I’ve been focusing more on performance tuning and scalable data solutions, and I’m looking to apply these skills to more complex, high-impact projects.
